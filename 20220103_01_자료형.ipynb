# %%
a = 123
a
# Out:
# 123

# %%
a = -178
a
# Out:
# -178

# %%
a = 1.2
a
# Out:
# 1.2

# %%
a = 0o177
a
# Out:
# 127

# %%
a = 0xFF
a
# Out:
# 255

# %%
a = 0
a
# Out:
# 0

# %%
a = -3.45
a
# Out:
# -3.45

# %%
a = 4.24E10
a
# Out:
# 42400000000.0

# %%
a = 4.24e-10
a
# Out:
# 4.24e-10

# %%
a = 4.24E-10
a
# Out:
# 4.24e-10

# %%
b = 0xABC
b
# Out:
# 2748

# %%
a = 3
b = 4
a + b
# Out:
# 7

# %%
a * b
# Out:
# 12

# %%
a / b
# Out:
# 0.75

# %%
a ** b
# Out:
# 81

# %%
a % b
# Out:
# 3

# %%
7 / 4
# Out:
# 1.75

# %%
7 // 4
# Out:
# 1

# %%
str = "hello world"
str
# Out:
# 'hello world'

# %%
type(str)
# Out:
# str

# %%
str1 = 'Python is fun'
str1
# Out:
# 'Python is fun'

# %%
str2 = """Life is too short, You need python"""
str2
# Out:
# 'Life is too short, You need python'

# %%
str3 = '''Life is too short, You need python'''
str3
# Out:
# 'Life is too short, You need python'

# %%
str4 = """Life
is too short,
You need python"""
str4
# Out:
# 'Life\nis too short,\nYou need python'

# %%
str5 = '''Life
is too short,
You need python'''
str5
# Out:
# 'Life\nis too short,\nYou need python'

# %%
str6 = '"I love you", he said'
str6
# Out:
# '"I love you", he said'

# %%
str7 = "it's mine"
str7
# Out:
# "it's mine"

# %%
food = "python's favorite food is perl"
food
# Out:
# "python's favorite food is perl"

# %%
say = '"python is very easy." he says.'
say
# Out:
# '"python is very easy." he says.'

# %%
food = 'python's favorite food is perl'
# Out:
#   File "<ipython-input-33-2fe3de20df8e>", line 1
#     food = 'python's favorite food is perl'
#                    ^
# SyntaxError: invalid syntax

# %%
food = 'python\'s favorite food is perl'
food
# Out:
# "python's favorite food is perl"

# %%
say = "\"python is very easy.\" he says."
say
# Out:
# '"python is very easy." he says.'

# %%
multiline = "Life is too short\nYou need python"
multiline
# Out:
# 'Life is too short\\nYou need python'

# %%
head = 'python'
tail = ' is fun!!!'

head + tail
# Out:
# 'python is fun!!!'

# %%
a = "python"

a * 2
# Out:
# 'pythonpython'

# %%
print('=' * 50)
print('my program')
print('=' * 50)
# Out:
# ==================================================
# my program
# ==================================================

# %%
a = "Life is too short"
len(a)
# Out:
# 17

# %%
a = "Life is too short, You need Python"
a[3]
# Out:
# 'e'

# %%
a[0]
# Out:
# 'L'

# %%
a[12]
# Out:
# 's'

# %%
a[-1]
# Out:
# 'n'

# %%
a[-0]
# Out:
# 'L'

# %%
a[-2]
# Out:
# 'o'

# %%
a[-5]
# Out:
# 'y'

# %%
b = a[0] + a[1] + a[2] + a[3]
b
# Out:
# 'Life'

# %%
a[0:4]
# Out:
# 'Life'

# %%
a[0:3]
# Out:
# 'Lif'

# %%
a[0:5]
# Out:
# 'Life '

# %%
a[0:2]
# Out:
# 'Li'

# %%
a[5:7]
# Out:
# 'is'

# %%
a[12:17]
# Out:
# 'short'

# %%
a[19:]
# Out:
# 'You need Python'

# %%
a[:17]
# Out:
# 'Life is too short'

# %%
a[:]
# Out:
# 'Life is too short, You need Python'

# %%
a[19:-7]
# Out:
# 'You need'

# %%
a = "20220103Sunny"
year = a[:4]
year
# Out:
# '2022'

# %%
month = a[4:6]
month
# Out:
# '01'

# %%
day = a[4:8]
day
# Out:
# '0103'

# %%
weather = a[-5:]
weather
# Out:
# 'Sunny'

# %%
weather = a[8:]
weather
# Out:
# 'Sunny'

# %%
a = 'pithon'
a[1]
# Out:
# 'i'

# %%
a[:1]
# Out:
# 'p'

# %%
a[2:]
# Out:
# 'thon'

# %%
a = a[:1] + 'y' + a[2:]
a
# Out:
# 'python'

# %%
'I eat %d apples.' % 3
# Out:
# 'I eat 3 apples.'

# %%
'I eat %s apples' % "five"
# Out:
# 'I eat five apple'

# %%
'I eat %s apples.' % 3
# Out:
# 'I eat 3 apples.'

# %%
n = 3
'I eat %s apples.' % n
# Out:
# 'I eat 3 apples.'

# %%
day = 'three'
"I ate %d apples. so I was sick for %s days." % (n, day)
# Out:
# 'I ate 3 apples. so I was sick for three days.'

# %%
'Error is %d%%.' % 98
# Out:
# 'Error is 98%.'

# %%
'Error is %d%.' % 98
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-310b3bebda66> in <module>()
# ----> 1 'Error is %d%.' % 98
#
# ValueError: incomplete format

# %%
'%10s' % 'hi'
# Out:
# '        hi'

# %%
'%-10sjane.' % 'hi'
# Out:
# 'hi        jane.'

# %%
'%0.4f' % 3.141592
# Out:
# '3.1416'

# %%
'%10.4f' % 3.141592
# Out:
# '    3.1416'

# %%
'%10.4f' % 3.42134234
# Out:
# '    3.4213'
