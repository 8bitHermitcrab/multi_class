# %%
"I eat {0} apples" .format(3)
# Out:
# 'I eat 3 apples'

# %%
'I eat {0} apples' .format('five')
# Out:
# 'I eat five apples'

# %%
number = 3
day = "three"
"I ate {0} apples. so I was sick for {1} days." . format(number, day)
# Out:
# 'I ate 3 apples. so I was sick for three days.'

# %%
"I ate {number} apples. so I was sick for {day} days." .format(number=10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days.'

# %%
"I ate {n} apples. so I was sick for {day} days." .format(n=10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days.'

# %%
'I ate {0} apples. so I was sick for {day} days.' .format(10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days.'

# %%
'{0:<10}' . format('hi')
# Out:
# 'hi        '

# %%
'{0:>10}' . format('hi')
# Out:
# '        hi'

# %%
'{0:^10}' . format('hi')
# Out:
# '    hi    '

# %%
'{0:=<10}' .format('hi')
# Out:
# 'hi========'

# %%
'{0:!<10}' .format('hi')
# Out:
# 'hi!!!!!!!!'

# %%
y = 3.42156
'{0:0.4f}' .format(y)
# Out:
# '3.4216'

# %%
y = 3.42156
'{0:10.4f}' .format(y)
# Out:
# '    3.4216'

# %%
'{{and}}'.format()
# Out:
# '{and}'

# %% [markdown]
# f-formating

# %%
name = '홍길동'
age = 30
f'나의 이름은 {name}입니다. 나이는 {age}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
age = 29
f'나는 내년이면 {age+1}살이 된다.'
# Out:
# '나는 내년이면 30살이 된다.'

# %%
d = {'name':'홍길동', 'age':30}
f'나의 이름은 {d["name"]}입니다. 나이는 {d["age"]}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
f'{"hi":<10}'
# Out:
# 'hi        '

# %%
f'{"hi":>10}'
# Out:
# '        hi'

# %%
f'{"hi":^10}'
# Out:
# '    hi    '

# %% [markdown]
# {[인덱스/값]:[공백을 채울 문자][정렬방식][자리수]}

# %%
# $
f'{"hi":$^10}'
# Out:
# '$$$$hi$$$$'

# %%
'{0}, {1}, {2}' .format('a', 'b', 'c')
# Out:
# 'a, b, c'

# %%
'{}, {}, {}' .format('a', 'b', 'c')
# Out:
# 'a, b, c'

# %%
'{2}, {1}, {0}' .format('a', 'b', 'c')
# Out:
# 'c, b, a'

# %%
'{2}, {1}, {0}' .format(*'abc')
# Out:
# 'c, b, a'

# %%
'{0}{1}{0}' .format('abra', 'cad')
# Out:
# 'abracadabra'

# %%
'Coordinate: {latitude}, {longitude}' .format(latitude='37.24N', longitude='-115.81W')
# Out:
# 'Coordinate: 37.24N, -115.81W'

# %%
coord = {'latitude':'37.24N', 'longitude':'-115.81W'}
'Coordinate: {latitude}, {longitude}' .format(**coord)
# Out:
# 'Coordinate: 37.24N, -115.81W'

# %% [markdown]
# ##문자열 함수

# %%
a = 'Hello World'
a.count('l')
# Out:
# 3

# %%
a = 'Python is the best choice'
a.find('b')
# Out:
# 14

# %%
a.find('k')
# Out:
# -1

# %%
a = 'Life is too short'
a.index('t')
# Out:
# 8

# %%
a.index('k')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-cb6c8ec35229> in <module>()
# ----> 1 a.index('k')
#
# ValueError: substring not found

# %%
',' .join('abcd')
# Out:
# 'a,b,c,d'

# %%
',' .join(['a', 'b', 'c', 'd'])
# Out:
# 'a,b,c,d'

# %%
a = 'Welcome'
a.upper()
# Out:
# 'WELCOME'

# %%
a.lower()
# Out:
# 'welcome'

# %%
a = '  hi  '
a.lstrip()
# Out:
# 'hi  '

# %%
a.rstrip()
# Out:
# '  hi'

# %%
a.alstrip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-510b2316e148> in <module>()
# ----> 1 a.alstrip()
#
# AttributeError: 'str' object has no attribute 'alstrip'

# %%
a.strip()
# Out:
# 'hi'

# %%
a = 'Life is too short'
a.replace('Life', 'Your leg')
# Out:
# 'Your leg is too short'

# %%
'Your leg' + a[4:]
# Out:
# 'Your leg is too short'

# %%
a
# Out:
# 'Life is too short'

# %%
a.split()
# Out:
# ['Life', 'is', 'too', 'short']

# %%
a = 'a:b:c:d'
a.split(':')
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# #리스트

# %%
odd = [1, 3, 5, 7, 9]
odd
# Out:
# [1, 3, 5, 7, 9]

# %%
odd[0]
# Out:
# 1

# %%
a = []
a
# Out:
# []

# %%
a = ['I', 'love', 'you']
a
# Out:
# ['I', 'love', 'you']

# %%
a = [1, 2, 'I', 'love', 'you']
a
# Out:
# [1, 2, 'I', 'love', 'you']

# %%
a = [1, 2, ['I', 'love', 'you']]
a
# Out:
# [1, 2, ['I', 'love', 'you']]

# %%
a = [1, 2, 3]
a[0]
# Out:
# 1

# %%
a[0] + a[2]
# Out:
# 4

# %%
a[-1]
# Out:
# 3

# %%
a = [1, 2, ['I', 'love', 'you']]
a[0]
# Out:
# 1

# %%
a[-1]
# Out:
# ['I', 'love', 'you']

# %%
a[3[2]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-418e3c23e537> in <module>()
# ----> 1 a[3[2]]
#
# TypeError: 'int' object is not subscriptable

# %%
a[-1][1]
# Out:
# 'love'

# %%
a = [1, 2, ['a', 'b', ['Life', 'is', 'good']]]
a
# Out:
# [1, 2, ['a', 'b', ['Life', 'is', 'good']]]

# %%
a[2][2][0]
# Out:
# 'Life'

# %%
a = [1, 2, ['a', 'b', ['Life', 'is', 'good', [3, 4, 5]]]]
a[2][2][3][0]
# Out:
# 3

# %%
d = {'name':'홍길동', 'age':30}
f'나의 이름은 {d['name']}입니다. 나이는 {d["age"]}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
'{0:!<10}' .format('hi')
# Out:
# 'hi!!!!!!!!'

# %%
'{0:10.4f}' .format(3.15351)
# Out:
# '    3.1535'
