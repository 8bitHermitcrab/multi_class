# %%
import numpy as np
# Out:
# 0.08079313589591118

# %% [markdown]
# # 1. 엔트로피

# %%
0.99*(-np.log2(0.99))+0.01*(-np.log2(0.01))
# Out:
# 0.08079313589591118

# %%
0.4*(-np.log2(0.4))+0.6*(-np.log2(0.6))
# Out:
# 0.9709505944546686

# %% [markdown]
# # 2. 지니 인덱스

# %%
# 사안A
1 - (((99/100)**2) + ((1/100)**2))
# Out:
# 0.01980000000000004

# %%
# 사안H
1 - (((4/10)**2) + ((6/10)**2))
# Out:
# 0.48

# %%
# G1
1 - (((2/4)**2) + ((2/4)**2))
# Out:
# 0.5

# %%
# G2
1 - (((2/5)**2) + ((3/5)**2))
# Out:
# 0.48

# %%
# 전체 : 분기 이전의 평균 정보량 (루트 상태)
1 - (((4/9)**2) + ((5/9)**2))
# Out:
# 0.49382716049382713

# %%
# 가중평균 : 분기 이후의 평균 정보량 (트리 상태)
(0.5 * 4/9) + (0.48 * 5/9)
# Out:
# 0.4888888888888889

# %%
# GL
1 - (((3/4)**2) + ((1/4)**2))
# Out:
# 0.375

# %%
# GR
1 - (((1/5)**2) + ((4/5)**2))
# Out:
# 0.31999999999999984

# %%
# 가중평균(G)
(0.375 * 4/9) + (0.32 * 5/9)
# Out:
# 0.34444444444444444

# %%
# IG : 정보 이득
0.49 - 0.344
# Out:
# 0.14600000000000002

# %% [markdown]
# # 3. 과제
#
# x 중복 제거 후 sort
#
# x = [1.0, 1.2, 2.2, 2.8, 3.5]
#
# 분기 후보
# 두값 사이의 평균값
# 분기 후보 = [1.1, 1.7, 2.5, 3.15]
#
# 분기 후보 중에 IG가 가장 큰 후보는?
# ex). 1.7일 경우, x >= 1.7
# 클래스
# N = [0, 1, 2]
# Y = [2, 0, 1]
#
# x = [1.0, 1.2]
# 분기는 x >= 1.1
# N = [0]
# Y = [1, 2]

# %% [markdown]
# 1. iris 데이터를 읽어오고, iris['data'][:, 0]
# 2. x의 첫번째 최적 분기 조건을 찾아라.
# 3. Gini index(지니 지수)를 사용한다.
#
# 중복 제거 후 sort
# 분기 후보 찾기
# 분기 후보중에 가장 큰 후보는?
#
# class = iris['target']

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import datasets

# %%
iris = load_iris()
x_train = iris['data'][:, 0]
y_train = iris['target']
# plt.scatter(x_train, y_train);
df = pd.DataFrame(data=np.c_[x_train, y_train], columns=['data', 'target'])
print(df)
# Out:
#      data  target
# 0     5.1     0.0
# 1     4.9     0.0
# 2     4.7     0.0
# 3     4.6     0.0
# 4     5.0     0.0
# ..    ...     ...
# 145   6.7     2.0
# 146   6.3     2.0
# 147   6.5     2.0
# 148   6.2     2.0
# 149   5.9     2.0
#
# [150 rows x 2 columns]

# %%
df['data']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: data, Length: 150, dtype: float64

# %%
len(iris['data'][:, 0])
# Out:
# 150

# %%
iris = load_iris()
# 1. 중복 제거 후 sort
# 중복 제거
unique_iris = (np.unique(x_train))
# 정렬
sorted_iris = np.sort(unique_iris)
print(sorted_iris)
# Out:
# [4.3 4.4 4.5 4.6 4.7 4.8 4.9 5.  5.1 5.2 5.3 5.4 5.5 5.6 5.7 5.8 5.9 6.
#  6.1 6.2 6.3 6.4 6.5 6.6 6.7 6.8 6.9 7.  7.1 7.2 7.3 7.4 7.6 7.7 7.9]

# %%
branch_iris = []
# 2. 분기 후보
for i in range(len(sorted_iris)-1):
  # print(f'sorted_iris[i] = {sorted_iris[i]}')
  a = (sorted_iris[i + 1] + sorted_iris[i]) / 2
  # print(f'branch_iris = {branch_iris}')
  branch_iris.append(a)
print(branch_iris)
# Out:
# [4.35, 4.45, 4.55, 4.65, 4.75, 4.85, 4.95, 5.05, 5.15, 5.25, 5.35, 5.45, 5.55, 5.65, 5.75, 5.85, 5.95, 6.05, 6.15, 6.25, 6.35, 6.45, 6.55, 6.65, 6.75, 6.85, 6.95, 7.05, 7.15, 7.25, 7.35, 7.5, 7.65, 7.800000000000001]

# %%
gini = []
for i branch_iris:
  left = < i
  right = > i

  G_L = 1
  G_R = 1

# %%
# 3. Groot 구하기
sum_iris_target = len(iris['target'])
a = iris['target']
unique, counts = np.unique(a, return_counts=True)
dict(zip(unique, counts))
# {0: 50, 1: 50, 2: 50}

# 전체 개수 = 150, 0의 개수 = 50, 1의 개수 = 50, 2의 개수 = 50
Groot = 1 - ((50/sum_iris_target) **2) + ((50/sum_iris_target) **2) + ((50/sum_iris_target) **2)
print(Groot)
# Out:
# 1.1111111111111112

# %%
list(set(iris['target']))
# Out:
# [0, 1, 2]

# %%
'''
tuple_iris = {}
for key in iris['target']:
  key = []
  key = iris['target']
print(f'key = {key}')
for value in iris['data'][:, 0]:
  value = []
  value = iris['data'][:, 0]
print(f'value = {value}')

for _ in range(150):
  tuple_iris[key] = value
print(tuple_iris)
'''

# %%
# 4. GT
result = []
for i in branch_iris:
  if i :
    a = 1 - (/sum_iris_target)
    result.append(a)
print(result)

# %%
# 5. 정보이득IG 구하기 (IG = Groot - GT)
sum_sorted_iris = len(sorted_iris)
# IG_Groot =
# Out:
# 35

# %% [markdown]
# # 다른 학생 코드

# %%
#
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# 데이터 읽어오기
iris = load_iris()

# 데이터 분류
x_train = iris['data'][:,0]
y_train = iris['target'].astype('int')

# plt.scatter(x_train, y_train);
df = pd.DataFrame(data=np.c_[x_train, y_train], columns=['data', 'target'])
print(df)

# div라는 분기후보들의 리스트 생성
x_range = list(set(x_train))
x_range.sort()
div = []
for i in range(len(x_range)-1):
  div.append((x_range[i]+x_range[i+1]) / 2)
print(div)

# div에 있는 분기후보들 각각의 Gini index를 찾아줌
gini = []
for i in div:
  left = df[df['data'] < i]['target'].to_numpy().astype('int')
  right = df[df['data'] > i]['target'].to_numpy().astype('int')
  G_L = 1
  G_R = 1
  for j in np.bincount(left):
    G_L -= (j/len(left))**2
  for k in np.bincount(right):
    G_R -= (k/len(right))**2
# Out:
#      data  target
# 0     5.1     0.0
# 1     4.9     0.0
# 2     4.7     0.0
# 3     4.6     0.0
# 4     5.0     0.0
# ..    ...     ...
# 145   6.7     2.0
# 146   6.3     2.0
# 147   6.5     2.0
# 148   6.2     2.0
# 149   5.9     2.0
#
# [150 rows x 2 columns]
# [4.35, 4.45, 4.55, 4.65, 4.75, 4.85, 4.95, 5.05, 5.15, 5.25, 5.35, 5.45, 5.55, 5.65, 5.75, 5.85, 5.95, 6.05, 6.15, 6.25, 6.35, 6.45, 6.55, 6.65, 6.75, 6.85, 6.95, 7.05, 7.15, 7.25, 7.35, 7.5, 7.65, 7.800000000000001]

# %%
#
# Root의 Gini index 계산
root_G = 1 - (len(df[df['target']==0.0])/len(y_train))**2 - (len(df[df['target']==1.0])/len(y_train))**2 - (len(df[df['target']==2.0])/len(y_train))**2
print(root_G)

# Information gain 계산
IG = []
for i in gini:
  IG.append(root_G - i)
print(IG)

# IG중 가장 큰값 찾은 후 해당분기 프린트
print(IG.index(max(IG)))
print(div[11])
# Out:
# 0.6666666666666665
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-660272c64c64> in <module>()
#      10
#      11 # IG중 가장 큰값 찾은 후 해당분기 프린트
# ---> 12 print(IG.index(max(IG)))
#      13 print(div[11])
#
# ValueError: max() arg is an empty sequence

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

iris = load_iris()
x_train = (iris['data'][:,0] * 0.8).reshape(-1, 1)
x_test = (iris['data'][:,0] * 0.2).reshape(-1, 1)
y_train = iris['target'] * 0.8
y_test = iris['target'] * 0.2

clf = DecisionTreeClassifier(max_depth = 2)
clf.fit(x_train, y_train)

# y를 추정
y_pred = clf.predict(x_test)

# y_pred와 y_test 비교
y_pred = clf.predict(np.array([12.0]).reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-f3ea4bbe1a62> in <module>()
#      11
#      12 clf = DecisionTreeClassifier(max_depth = 2)
# ---> 13 clf.fit(x_train, y_train)
#      14
#      15 # y를 추정
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     940             sample_weight=sample_weight,
#     941             check_input=check_input,
# --> 942             X_idx_sorted=X_idx_sorted,
#     943         )
#     944         return self
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     201
#     202         if is_classification:
# --> 203             check_classification_targets(y)
#     204             y = np.copy(y)
#     205
#
# ...

# %% [markdown]
# # 의사결정나무 사용하기

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt
iris = load_iris()

x_train, x_test, y_train, y_test = train_test_split(iris['data'], iris['target'], test_size=0.2)

# max_depth = 1~20까지 중에 정확도가 가장 큰 것으로
score = []
for k in range(1, 21):
  clf = DecisionTreeClassifier(max_depth=k)
  clf.fit(x_train, y_train)
  a = clf.score(x_test, y_test)
  score.append(a)

# print(score)
print(f' 1~20까지 중에 정확도가 가장 큰 것 : {(score.index(max(score))+1)}')
# Out:
#  1~20까지 중에 정확도가 가장 큰 것 : 2

# %%
x_new = np.array([2.3, 1.0, 3.2, 2.5]).reshape(-1, 1)
dt.predict(x_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-cf2b22ee9e9d> in <module>()
#       1 x_new = np.array([2.3, 1.0, 3.2, 2.5]).reshape(-1, 1)
# ----> 2 dt.predict(x_new)
#
# NameError: name 'dt' is not defined

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt

df = pd.read_csv('diabetes.csv')
print(df)

# df.drop(['Outcome'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(df.drop(['Outcome'], axis=1), df['Outcome'], test_size=0.2)
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
# dtree

# k를 변화시켜가면서 정확도를 측정해 본다
acc_test = []
acc_train = []
d_max = 30
for d in range(1, d_max):
    # KNN 으로 학습 데이터 세트를 학습한다.
    dt = DecisionTreeClassifier(max_depth=d)
    dt.fit(x_train, y_train)
    
    # 시험 데이터의 Feature에 대한 정확도
    y_pred = dt.predict(x_test)
    acc_test.append((y_test == y_pred).mean())
    
    # 학습 데이터의 Feature에 대한 정확도
    y_pred = dt.predict(x_train)
    acc_train.append((y_train == y_pred).mean())

plt.figure(figsize=(8, 5))
plt.plot(acc_test, marker='o', label="Test Data")
plt.plot(acc_train, marker='o', label="Train Data")
plt.legend()
plt.xlabel("ma_depth")
plt.ylabel("Accuracy")
plt.xticks(np.arange(d_max), np.arange(1, d_max + 1))
plt.show()

opt_depth = np.argmax(acc_test)
opt_acc = acc_test[opt_depth]

print("optimal depth = {}, accuracy = {:.3f}".format(opt_depth + 1, opt_acc))

x_new = np.array([3, 127, 85, 25, 473, 27, 25, 37]).reshape(-1, 8)
y_new_pred = dt.predict(x_new)

if y_new_pred[0] == 0:
  print('이 환자는 당뇨병이 아닙니다.')
else:
  print('이 환자는 당뇨병입니다.')

print('이 추정의 정확도 = {:.2f}%'.format(opt_acc * 100))
# Out:
# optimal depth = 4, accuracy = 0.753
# 이 환자는 당뇨병입니다.
# 이 추정의 정확도 = 75.32%
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
# knn

# k를 변화시켜가면서 정확도를 측정해 본다
acc_test = []
acc_train = []
k_max = 30
for k in range(1, k_max):
    # KNN 으로 학습 데이터 세트를 학습한다.
    knn = KNeighborsClassifier(n_neighbors=k, p=2, weights='uniform')
    knn.fit(x_train, y_train)
    
    # 시험 데이터의 Feature에 대한 정확도
    y_pred = knn.predict(x_test)
    acc_test.append((y_test == y_pred).mean())
    
    # 학습 데이터의 Feature에 대한 정확도
    y_pred = knn.predict(x_train)
    acc_train.append((y_train == y_pred).mean())

plt.figure(figsize=(8, 5))
plt.plot(acc_test, marker='o', label="Test Data")
plt.plot(acc_train, marker='o', label="Train Data")
plt.legend()
plt.xlabel("k")
plt.ylabel("Accuracy")
plt.xticks(np.arange(k_max), np.arange(1, k_max + 1))
plt.show()

opt_k = np.argmax(acc_test)
opt_acc = acc_test[opt_k]

print("optimal k = {}, accuracy = {:.3f}".format(opt_k + 1, opt_acc))

x_new = np.array([3, 127, 85, 25, 473, 27, 25, 37]).reshape(-1, 8)
dt.predict(x_new)

if y_new_pred[0] == 0:
  print('이 환자는 당뇨병이 아닙니다.')
else:
  print('이 환자는 당뇨병입니다.')

print('이 추정의 정확도 = {:.2f}%'.format(opt_acc * 100))
# Out:
# optimal k = 11, accuracy = 0.747
# 이 환자는 당뇨병입니다.
# 이 추정의 정확도 = 74.68%
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
# -*- coding: utf-8 -*-
"""KNN(diabates).ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1xwkHiZAOvjpZF654ZUsLVSNz3L1vWoZ1
"""

import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import pandas as pd

# diabetes 데이터를 읽어온다
DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/data/'
data = pd.read_csv(DATA_PATH + 'diabetes.csv')
data.head()

# 학습 데이터와 시험 데이터로 분리한다.
x_feat = np.array(data.drop('Outcome', axis=1))
y_target = np.array(data['Outcome'])

x_train, x_test, y_train, y_test = train_test_split(x_feat, y_target, test_size=0.2)

# K를 변화시켜가면서 정확도를 측정해 본다
acc_test = []
acc_train = []
k_max = 20
for k in range(1, k_max):
    # Decision Tree로 학습 데이터 세트를 학습한다.
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    
    # 시험 데이터와 학습 데이터의 정확도를 측정한다.
    acc_test.append(knn.score(x_test, y_test))
    acc_train.append(knn.score(x_train, y_train))

plt.figure(figsize=(6, 4))
plt.plot(acc_test, marker='o', label="Test Data")
plt.plot(acc_train, marker='o', label="Train Data")
plt.legend()
plt.xlabel("K")
plt.ylabel("Accuracy")
plt.xticks(np.arange(k_max), np.arange(1, k_max + 1))
plt.show()

opt_k = np.argmax(acc_test)
opt_acc = acc_test[opt_k]

print("optimal depth = {}, accuracy = {:.3f}".format(opt_k + 1, opt_acc))

# 활용
x_new = np.array([3, 127, 85, 25, 473, 27, 25, 37]).reshape(-1,8)
y_pred = knn.predict(x_new)

if y_pred[0] == 0:
    print('"이 환자는 당뇨병이 아님"으로 진단함')
else:
    print('"이 환자는 당뇨병임"으로 진단함')

print("추정의 정확도 = {:.2f}%".format(opt_acc * 100))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-160-76a5201d19d0> in <module>()
#      17 # diabetes 데이터를 읽어온다
#      18 DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/data/'
# ---> 19 data = pd.read_csv(DATA_PATH + 'diabetes.csv')
#      20 data.head()
#      21
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
